# %% [markdown]
# # How much gets filtered when removing rRNA, tRNA, and mtDNA/RNA?
# # Notebook 1: fetching the data
# I'm making this notebook as a n intermission from preparing rolypoly external database. So far I've used a combination of NCBI +SILVA rRNAs to remove contaminating rRNA reads from RNA-seq data. Subsequently, the organisms whose rRNAs were most matched, are then also fetched (or their transcriptomes, if available) to remove any remaining reads that may have come from those organisms.
# THis is messy, requires NCBI taxdump, taxonkit, and ncbi-datasets. So I started removing this dependency by using a set of rRNAs for which I can generate a prebuilt table containing the FTP addresses of the hosts' genomes/transcriptomes.
# While doing so, I realised the step above could be split - quick rRNA mapping to get rough taxonomic breakdown of the sample, and then a more thorough removal of rRNA, tRNA, and mtDNA/RNA using a more comprehensive database. The question is then how much will these diffrent combinations filter, how much more time, and would masking the fasta for subsequences shared with RNA viruses change the results significantly?
#
# To test these, below are how I got the data, how I named the sets. For simplicity, the [trrna_fetch.ipynb](trrna_fetch.ipynb) has the code for the actual filtering using these sequence typs, graphs and so on.

# %% [markdown]
# *Note*: Parts of this script are from [build_data.py](../src/rolypoly/commands/misc/build_data.py) and [filter_reads.py](../src/rolypoly/commands/reads/filter_reads.py) scripts in the rolypoly repository.

# %% [markdown]
# Loading libraries and defining paths to sets already created/downloaded:

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import json
import logging
import shutil
import subprocess
import tarfile
from pathlib import Path as pt
import aria2p
import tempfile
import hashlib
import os
import time
import ftplib
from ftplib import FTP
import glob
from collections import defaultdict, deque
import heapq

import polars as pl
import requests
from tqdm.notebook import tqdm
from bbmapy import bbduk, bbmask, kcompress
from rich.console import Console
from rich_click import command, option

from rolypoly.utils.bio.alignments import (
    hmmdb_from_directory,
    mmseqs_profile_db_from_directory,
)
from rolypoly.utils.bio.sequences import (
    filter_fasta_by_headers,
    write_fasta_file,
    remove_duplicates
)

from rolypoly.utils.bio.trees import TaxonomyTree

from rolypoly.utils.bio.polars_fastx import from_fastx_eager

from rolypoly.utils.logging.citation_reminder import remind_citations
from rolypoly.utils.logging.loggit import get_version_info, setup_logging
from rolypoly.utils.various import fetch_and_extract, run_command_comp,extract

### DEBUG ARGS (for manually building, not entering via CLI):
threads = 6
log_file = "notebooks/Exprimental/trrna.log"
global data_dir
data_dir = "<REPO_PATH>/data"
os.environ["ROLYPOLY_DATA_DIR"] = data_dir

global rrna_dir
global contam_dir

logger = setup_logging(log_file)
print(f"Starting data preparation to : {data_dir}")

contam_dir = os.path.join(data_dir, "contam")
os.makedirs(contam_dir, exist_ok=True)

rrna_dir = os.path.join(contam_dir, "rrna")
os.makedirs(rrna_dir, exist_ok=True)

trna_dir = os.path.join(contam_dir, "trna")
os.makedirs(trna_dir, exist_ok=True)

masking_dir = os.path.join(contam_dir, "masking")
os.makedirs(masking_dir, exist_ok=True)

reference_seqs = os.path.join(data_dir, "reference_seqs")
os.makedirs(reference_seqs, exist_ok=True)

mmseqs_ref_dir = os.path.join(reference_seqs, "mmseqs")
os.makedirs(mmseqs_ref_dir, exist_ok=True)

rvmt_dir = os.path.join(reference_seqs, "RVMT")
os.makedirs(rvmt_dir, exist_ok=True)

ncbi_ribovirus_dir = os.path.join(reference_seqs, "ncbi_ribovirus")
os.makedirs(ncbi_ribovirus_dir, exist_ok=True)

# Masking sequences preparation
rvmt_fasta_path = os.path.join(
    data_dir, "reference_seqs", "RVMT", "RVMT_cleaned_contigs.fasta"
)
ncbi_ribovirus_fasta_path = os.path.join(
    data_dir,
    "reference_seqs",
    "ncbi_ribovirus",
    "refseq_ribovirus_genomes.fasta",
)

rna_viruses_entropy_masked_path = os.path.join(
    masking_dir, "combined_entropy_masked.fasta"
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Starting data preparation to : <REPO_PATH>/data

# %% [markdown]
# ## Fetching data (SILVA, NCBI rRNAs, tRNAs, mtDNAs):

# %%
silva_release = "138.2"

# Download SILVA rRNA sequences (SSU and LSU)
silva_ssu_path = os.path.join(
    rrna_dir, f"SILVA_{silva_release}_SSURef_NR99_tax_silva.fasta"
)
silva_lsu_path = os.path.join(
    rrna_dir, f"SILVA_{silva_release}_LSURef_NR99_tax_silva.fasta"
)
# skipping downloading (already done)
fetch_and_extract(
    f"https://www.arb-silva.de/fileadmin/silva_databases/release_{silva_release.replace('.', '_')}/Exports/SILVA_{silva_release}_SSURef_NR99_tax_silva.fasta.gz",
    fetched_to=os.path.join(rrna_dir, "tmp_ssu.fasta.gz"),
    extract_to=rrna_dir,
    rename_extracted=silva_ssu_path,
    logger=logger,
)
fetch_and_extract(
    f"https://www.arb-silva.de/fileadmin/silva_databases/release_{silva_release.replace('.', '_')}/Exports/SILVA_{silva_release}_LSURef_NR99_tax_silva.fasta.gz",
    fetched_to=os.path.join(rrna_dir, "tmp_lsu.fasta.gz"),
    extract_to=rrna_dir,
    rename_extracted=silva_lsu_path,
    logger=logger,
)

# Download SILVA taxonomy mappings (maps accessions to NCBI taxids)
silva_ssu_taxmap = pl.read_csv(
    "https://www.arb-silva.de/fileadmin/silva_databases/current/Exports/taxonomy/ncbi/taxmap_embl-ebi_ena_ssu_ref_nr99_138.2.txt.gz",
    truncate_ragged_lines=True,
    separator="\t",
    infer_schema_length=123123,
)
silva_lsu_taxmap = pl.read_csv(
    "https://www.arb-silva.de/fileadmin/silva_databases/current/Exports/taxonomy/ncbi/taxmap_embl-ebi_ena_lsu_ref_nr99_138.2.txt.gz",
    truncate_ragged_lines=True,
    separator="\t",
    infer_schema_length=123123,
)
silva_taxmap = pl.concat([silva_lsu_taxmap, silva_ssu_taxmap])
silva_taxmap.write_parquet(os.path.join(rrna_dir, "silva_taxmap_embl-ebi_ena.parquet"))
# Out:
# INFO     2025-12-28 22:53:33 - Downloading                                                                                              ]8;id=664730;file://<REPO_PATH>/src/rolypoly/utils/various.py\various.py]8;;\:]8;id=737937;file://<REPO_PATH>/src/rolypoly/utils/various.py#215\215]8;;\
#          https://www.arb-silva.de/fileadmin/silva_databases/release_138_2/Exports/SILVA_138.2_SSURef_NR99_tax_silva.fasta.gz to
#          <REPO_PATH>/data/contam/rrna/tmp_ssu.fasta.gz
# INFO     2025-12-28 22:54:01 - Successfully downloaded to                                                                               ]8;id=74975;file://<REPO_PATH>/src/rolypoly/utils/various.py\various.py]8;;\:]8;id=787093;file://<REPO_PATH>/src/rolypoly/utils/various.py#221\221]8;;\
#          <REPO_PATH>/data/contam/rrna/tmp_ssu.fasta.gz
# INFO     2025-12-28 22:54:01 - Extracting <REPO_PATH>/data/contam/rrna/tmp_ssu.fasta.gz   ]8;id=479798;file://<REPO_PATH>/src/rolypoly/utils/various.py\various.py]8;;\:]8;id=958292;file://<REPO_PATH>/src/rolypoly/utils/various.py#255\255]8;;\
#          to <REPO_PATH>/data/contam/rrna
# INFO     2025-12-28 22:54:05 - Successfully extracted to                                                                                ]8;id=463229;file://<REPO_PATH>/src/rolypoly/utils/various.py\various.py]8;;\:]8;id=894040;file://<REPO_PATH>/src/rolypoly/utils/various.py#288\288]8;;\
#          <REPO_PATH>/data/contam/rrna/tmp_ssu.fasta
# INFO     2025-12-28 22:54:05 - Downloading                                                                                              ]8;id=306869;file://<REPO_PATH>/src/rolypoly/utils/various.py\various.py]8;;\:]8;id=962956;file://<REPO_PATH>/src/rolypoly/utils/various.py#215\215]8;;\
#          https://www.arb-silva.de/fileadmin/silva_databases/release_138_2/Exports/SILVA_138.2_LSURef_NR99_tax_silva.fasta.gz to
#          <REPO_PATH>/data/contam/rrna/tmp_lsu.fasta.gz
# INFO     2025-12-28 22:54:13 - Successfully downloaded to                                                                               ]8;id=789217;file://<REPO_PATH>/src/rolypoly/utils/various.py\various.py]8;;\:]8;id=399592;file://<REPO_PATH>/src/rolypoly/utils/various.py#221\221]8;;\
#          <REPO_PATH>/data/contam/rrna/tmp_lsu.fasta.gz
# INFO     2025-12-28 22:54:13 - Extracting <REPO_PATH>/data/contam/rrna/tmp_lsu.fasta.gz   ]8;id=673944;file://<REPO_PATH>/src/rolypoly/utils/various.py\various.py]8;;\:]8;id=359225;file://<REPO_PATH>/src/rolypoly/utils/various.py#255\255]8;;\
#          to <REPO_PATH>/data/contam/rrna
# INFO     2025-12-28 22:54:15 - Successfully extracted to                                                                                ]8;id=769819;file://<REPO_PATH>/src/rolypoly/utils/various.py\various.py]8;;\:]8;id=785533;file://<REPO_PATH>/src/rolypoly/utils/various.py#288\288]8;;\
#          <REPO_PATH>/data/contam/rrna/tmp_lsu.fasta

# %%
# Parse SILVA headers and extract accessions
silva_fasta_df = pl.concat(
    [
        from_fastx_eager(silva_ssu_path).with_columns(
            pl.lit("SSU").alias("rRNA_type")
        ),
        from_fastx_eager(silva_lsu_path).with_columns(
            pl.lit("LSU").alias("rRNA_type")
        ),
    ]
)
silva_fasta_df.write_parquet(os.path.join(rrna_dir, "silva99_fasta.parquet"))
print(f"total SILVA99 sequences {silva_fasta_df.height}")
silva_fasta_df.head(4)
# Out:
# total SILVA99 sequences 605774
# shape: (4, 3)
# ┌─────────────────────────────────┬─────────────────────────────────┬───────────┐
# │ header                          ┆ sequence                        ┆ rRNA_type │
# │ ---                             ┆ ---                             ┆ ---       │
# │ str                             ┆ str                             ┆ str       │
# ╞═════════════════════════════════╪═════════════════════════════════╪═══════════╡
# │ AY846379.1.1791 Eukaryota;Arch… ┆ AACCUGGUUGAUCCUGCCAGUAGUCAUAUG… ┆ SSU       │
# │ AY846382.1.1778 Eukaryota;Arch… ┆ GUUGAUCCUGCCAGUAGUCAUAUGCUUGUC… ┆ SSU       │
# │ AB000393.1.1510 Bacteria;Pseud… ┆ UGGCUCAGAUUGAACGCUGGCGGCAGGCCU… ┆ SSU       │
# │ AY909590.1.2352 Eukaryota;Arch… ┆ GACUAAGCCAUGCAUGUCUAAGUAUAAACG… ┆ SSU       │
# └─────────────────────────────────┴─────────────────────────────────┴───────────┘

# %%
# Extract accession from header (format: >accession.version rest_of_header)
silva_fasta_df = silva_fasta_df.with_columns(
    primaryAccession=pl.col("header").str.extract(
        r"^([A-Za-z0-9_]+)(?:\.\d+)*", 1
    ),  # DQ150555.1.2478 -> DQ150555
    accession=pl.col("header").str.extract(
        r"^([A-Za-z0-9_]+(?:\.\d+)?)", 1
    ),  # AY846379 or DQ150555.1
    taxonomy_raw=pl.col("header").str.replace(r"^\S+\s+", ""),
)
    # silva_fasta_df = silva_fasta_df.with_columns(
    #     pl.col("sequence").str.len_chars().alias("seq_length")
    # )
    # silva_taxmap = silva_taxmap.with_columns(
    #     (pl.col("stop") - pl.col("start")).alias("seq_length")
    # )

silva_df = silva_fasta_df.join(
    silva_taxmap.select(
        ["primaryAccession", "ncbi_taxonid", "submitted_path"]
    ).unique(),  # seq_length
    on=["primaryAccession"],
    how="inner",
)
# silva_df.height
silva_df["ncbi_taxonid"].null_count()

# Load SILVA taxonomy mappings
print(
    f"Merged taxonomy for {silva_df.filter(pl.col('ncbi_taxonid').is_not_null()).height} SILVA sequences"
)

unique_taxids = (
    silva_df.filter(pl.col("ncbi_taxonid").is_not_null())
    .select("ncbi_taxonid")
    .unique()["ncbi_taxonid"]
    .to_list()
)
print(
    f"Total of {len(unique_taxids)} unique NCBI taxids found in SILVA sequences"
)
# Out:
# Merged taxonomy for 605774 SILVA sequences
# Total of 105645 unique NCBI taxids found in SILVA sequences

# %%
silva_df["ncbi_taxonid"].value_counts(sort=True).head(10)
# Out:
# shape: (10, 2)
# ┌──────────────┬────────┐
# │ ncbi_taxonid ┆ count  │
# │ ---          ┆ ---    │
# │ i64          ┆ u32    │
# ╞══════════════╪════════╡
# │ 77133        ┆ 183357 │
# │ 155900       ┆ 19293  │
# │ 115547       ┆ 12243  │
# │ 256318       ┆ 7959   │
# │ 562          ┆ 7811   │
# │ 100272       ┆ 6908   │
# │ 136703       ┆ 5459   │
# │ 573          ┆ 4190   │
# │ 1280         ┆ 3213   │
# │ 171953       ┆ 2670   │
# └──────────────┴────────┘

# %% [markdown]
# Removing 77133,155900,115547,256318,100272,136703,171953,86473 (uncultured) as they are not useful for genome fetching later on.
# Also removing things wiht "uncultured" in the submitted_path.

# %%
import hashlib
silva_df = silva_df.with_columns(
    t1=pl.concat_str([pl.col("ncbi_taxonid"),pl.lit("silva"),pl.col("rRNA_type")],separator="@")).with_columns(
    new_header =pl.concat_str([pl.col("t1"),pl.col("header")],separator=" ")
)
silva_df = silva_df.with_columns(
    t1=pl.concat_str([pl.col("ncbi_taxonid"),pl.lit("silva"),pl.col("rRNA_type")],separator="@")
    )

silva_df = silva_df.with_columns(
    pl.col("sequence").map_elements(lambda x: hashlib.md5(x.encode()).hexdigest()).alias("seq_hash"),
).with_columns(
    new_header = pl.concat_str([pl.col("t1"),pl.col("seq_hash")],separator="@")
    
)
silva_df = silva_df.unique()
silva_df = silva_df.unique(subset=["sequence"])
silva_df = silva_df.drop("t1")

silva_df["new_header"].head(1).item()

heigt_befrore= silva_df.height
print(silva_df.height)
silva_df = silva_df.filter(~pl.col("ncbi_taxonid").is_in([77133,155900,115547,256318,100272,136703,171953,86473,56765]))
silva_df = silva_df.filter(~pl.col("submitted_path").str.contains_any(["uncultured","unclassified","synthetic","environmental sample"]))

print(silva_df.height)
for coln in silva_df.columns:
    print(coln)
    print(silva_df[coln].sample(5).to_list())

silva_df.write_parquet(os.path.join(rrna_dir, "silva_rrna_sequences.parquet"))
print("Finished writing SILVA rRNA sequences parquet file.")
print(f"total SILVA sequences after filtering: {silva_df.height}, removed {heigt_befrore - silva_df.height} sequences")
# Out:
# 530930
# 226832
# header
# ['FN773278.1.1468 Bacteria;Campylobacterota;Campylobacteria;Campylobacterales;Sulfurospirillaceae;Sulfurospirillum;bacterium endosymbiont of Osedax mucofloris', 'AF163120.1.1458 Bacteria;Actinomycetota;Actinobacteria;Streptosporangiales;Thermomonosporaceae;Actinoallomurus;Actinoallomurus spadix', 'CP022663.4249352.4250905 Bacteria;Pseudomonadota;Gammaproteobacteria;Enterobacterales;Enterobacteriaceae;Salmonella;Salmonella enterica', 'EU136629.1.1439 Bacteria;Pseudomonadota;Gammaproteobacteria;Enterobacterales;Pseudoalteromonadaceae;Pseudoalteromonas;Pseudoalteromonas sp. Z6', 'KC984863.1.1291 Bacteria;Pseudomonadota;Gammaproteobacteria;Pseudomonadales;Halomonadaceae;Halomonas;Halomonas sp. UADY-002']
# sequence
# ['...', '...', '...', '...', '...']
# rRNA_type
# ['SSU', 'LSU', 'SSU', 'SSU', 'LSU']
# primaryAccession
# ['AY281078', 'AB915216', 'Y17190', 'EF423414', 'DQ631734']
# accession
# ['CP018007.2993062', 'AJ295716.1', 'MKYQ01000782.2648941', 'CP023149.1613845', 'MG203880.1']
# taxonomy_raw
# ['Bacteria;Pseudomonadota;Gammaproteobacteria;Enterobacterales;Enterobacteriaceae;Escherichia-Shigella;Escherichia coli', 'Bacteria;Pseudomonadota;Gammaproteobacteria;Pseudomonadales;Pseudomonadaceae;Pseudomonas;Pseudomonas fluorescens A506', 'Eukaryota;Archaeplastida;Chloroplastida;Charophyta;Phragmoplastophyta;Gossypium hirsutum (upland cotton)', 'Bacteria;Bacillota;Bacilli;Bacillales;Bacillaceae;Priestia;Bacillus flexus', 'Bacteria;Pseudomonadota;Gammaproteobacteria;Enterobacterales;Enterobacteriaceae;Klebsiella;Klebsiella oxytoca']
# ncbi_taxonid
# [393060, 2077137, 231022, 435910, 216107]
# submitted_path
# ['Bacteria;Firmicutes;Clostridia;Clostridiales;Clostridiaceae;Clostridium;', 'Bacteria;Proteobacteria;Gammaproteobacteria;Enterobacterales;Yersiniaceae;Yersinia;', 'Bacteria;Proteobacteria;Gammaproteobacteria;Enterobacterales;Yersiniaceae;Serratia;', 'Eukaryota;Viridiplantae;Streptophyta;Embryophyta;Tracheophyta;Spermatophyta;Magnoliophyta;eudicotyledons;Gunneridae;Pentapetalae;rosids;malvids;Malvales;Malvaceae;Malvoideae;Gossypium;', 'Bacteria;Fusobacteria;Fusobacteriales;Fusobacteriaceae;Fusobacterium;']
# new_header
# ['672@silva@LSU@2d164a3f1bb9ebd83210e6ec54eb6bbf', '294@silva@SSU@d73bdd1b0e1d43b44b1670f7a3eb74b7', '37333@silva@SSU@faf880eb4f8cd066471abbba70f09b3a', '1396@silva@SSU@8089e3257f22c07c272e0f4aa8cc01e8', '376815@silva@SSU@2dab3f95e66688bc564b2a0c92edcf0e']
# seq_hash
# ['ce611f478fc73f8bbdae928d9f332c37', '51b7355bac448663b370a6ecb53da516', '3b14a2d467be501ede25a223cd80bd00', '07f19fb3fb68d9f2740ea2f185cf7dfc', '8e12e8db52a1696ebdab61152c4c7b7d']
# Finished writing SILVA rRNA sequences parquet file.
# total SILVA sequences after filtering: 226832, removed 304098 sequences

# %% [markdown]
# Deduplicate, mask kmers shared with RNA viruses, and apply entrophy masking.

# %%
from rolypoly.commands.reads import mask_dna
import rich_click as click
import hashlib
#replace headers with md5 hash as the new_header breaks mappers. Will remap after this
silva_df = silva_df.with_columns(
    pl.col("sequence").map_elements(lambda x: hashlib.md5(x.encode()).hexdigest()).alias("tmp_header")
)

write_fasta_file(
    headers=silva_df["tmp_header"].to_list(),
    seqs=silva_df["sequence"].to_list(),
    output_file=os.path.join(rrna_dir, "temp_silva_rrna_sequences.fasta"),
)
# deduplicate sequences
deduplicated_silva_fasta_path = os.path.join(
    rrna_dir, "silva_rrna_sequences_deduplicated.fasta"
)
remove_duplicates(
    input_file=os.path.join(rrna_dir, "temp_silva_rrna_sequences.fasta"),
    output_file=deduplicated_silva_fasta_path,
    logger=logger,
    by="seq",
    # revcomp_as_distinct=False
)
# Out:
# INFO     2025-12-28 22:55:14 - Processed 226832 records: 226832 unique, 0 duplicates removed                                          ]8;id=852034;file://<REPO_PATH>/src/rolypoly/utils/bio/sequences.py\sequences.py]8;;\:]8;id=718033;file://<REPO_PATH>/src/rolypoly/utils/bio/sequences.py#725\725]8;;\

# %%
# mask shared kmers with RNA viruses
masked_silva_fasta_path = os.path.join(
    rrna_dir, "silva_rrna_sequences_deduplicated_masked.fasta"
)
entrophy_masked_silva_fasta_path = os.path.join(
    rrna_dir, "silva_rrna_sequences_deduplicated_masked_entropy.fasta"
)

mask_args = {"threads": 14,
            "memory": "18gb",
            "output": str(masked_silva_fasta_path),
            "flatten": False,
            "aligner":"mmseqs2",
            "input": str(deduplicated_silva_fasta_path)
        }

# ensure we have the click Command object (the package import may have bound the module)
from rolypoly.commands.reads.mask_dna import mask_dna as _mask_cmd

# If it's a click.Command use a Context to invoke, otherwise call directly
if isinstance(_mask_cmd, click.core.Command):
    ctx = click.Context(_mask_cmd)
    ctx.invoke(_mask_cmd, **mask_args)
else:
    # fallback: call the function directly
    _mask_cmd(**mask_args)

# # Apply entropy masking
bbduk(
    in1=masked_silva_fasta_path,
    out=entrophy_masked_silva_fasta_path,
    entropy=0.4,
    entropyk=4,
    entropywindow=24,
    maskentropy=True,
    ziplevel=9,
)


# read the masked fasta and remap to original headers
silva_rrna_masked_df = from_fastx_eager(entrophy_masked_silva_fasta_path).rename({"header":"tmp_header","sequence":"masked_sequence"})
silva_rrna_masked_df = silva_rrna_masked_df.join(
    silva_df,
    on=["tmp_header"],
    how="inner",
)
silva_rrna_masked_df.write_parquet(os.path.join(rrna_dir, "silva_rrna_sequences_masked.parquet"))
print("Finished writing SILVA rRNA sequences parquet file.")
write_fasta_file(
    headers=silva_rrna_masked_df["new_header"].to_list(),
    seqs=silva_rrna_masked_df["masked_sequence"].to_list(),
    output_file=os.path.join(rrna_dir, "silva_rRNA_all_sequences_masked_entropy.fasta"),
)
print(f"finished writing masked SILVA rRNA fasta file: {os.path.join(rrna_dir, 'silva_rRNA_all_sequences_masked_entropy.fasta')}")
# Out:
# INFO     2025-12-28 22:55:34 - datadir used: <REPO_PATH>/data                             ]8;id=325631;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py\mask_dna.py]8;;\:]8;id=88559;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py#71\71]8;;\
# Running command: mmseqs easy-linsearch <REPO_PATH>/data/contam/masking/combined_entropy_masked.fasta <REPO_PATH>/data/contam/rrna/silva_rrna_sequences_deduplicated.fasta <REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam <REPO_PATH>/data/contam/rrna/tmp_mask_dna  --min-seq-id 0.7 --min-aln-len 80 --threads 14 --format-mode 1 --search-type 3 -v 3 --max-accept 1231 -a
# easy-linsearch <REPO_PATH>/data/contam/masking/combined_entropy_masked.fasta <REPO_PATH>/data/contam/rrna/silva_rrna_sequences_deduplicated.fasta <REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam <REPO_PATH>/data/contam/rrna/tmp_mask_dna --min-seq-id 0.7 --min-aln-len 80 --threads 14 --format-mode 1 --search-type 3 -v 3 --max-accept 1231 -a
#
# MMseqs Version:                    	18.8cc5c
# Substitution matrix                	aa:blosum62.out,nucl:nucleotide.out
# Add backtrace                      	true
# Alignment mode                     	3
# Alignment mode                     	0
# Allow wrapped scoring              	false
# E-value threshold                  	0.001
# Seq. id. threshold                 	0.7
# Min alignment length               	80
# Seq. id. mode                      	0
# Alternative alignments             	0
# Coverage threshold                 	0
# Coverage mode                      	0
# Max sequence length                	65535
# Compositional bias                 	1
# Compositional bias scale           	1
# Max reject                         	2147483647
# Max accept                         	1231
# Include identical seq. id.         	false
# Preload mode                       	0
# Pseudo count a                     	substitution:1.100,context:1.400
# Pseudo count b                     	substitution:4.100,context:5.800
# Score bias                         	0
# Realign hits                       	false
# Realign score bias                 	-0.2
# Realign max seqs                   	2147483647
# Correlation score weight           	0
# Gap open cost                      	aa:11,nucl:5
# Gap extension cost                 	aa:1,nucl:2
# Zdrop                              	40
# Threads                            	14
# Compressed                         	0
# Verbosity                          	3
# Seed substitution matrix           	aa:VTML80.out,nucl:nucleotide.out
# k-mers per sequence                	21
# Scale k-mers per sequence          	aa:0.000,nucl:0.200
# Mask residues                      	1
# Mask residues probability          	0.9
# Mask lower case residues           	0
# Mask lower letter repeating N times	0
# Add N similar to search            	1
# Result direction                   	1
# Split memory limit                 	0
# Min codons in orf                  	30
# Max codons in length               	32734
# Max orf gaps                       	2147483647
# Contig start mode                  	2
# Contig end mode                    	2
# Orf start mode                     	1
# Forward frames                     	1,2,3
# Reverse frames                     	1,2,3
# Translation table                  	1
# Translate orf                      	0
# Use all table starts               	false
# Offset of numeric ids              	0
# Create lookup                      	0
# Chain overlapping alignments       	0
# Merge query                        	1
# Search type                        	3
# MPI runner
# Force restart with latest tmp      	false
# Remove temporary files             	true
# Alignment format                   	1
# Format alignment output            	query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits
# Database output                    	false
#
# Alignment backtraces will be computed, since they were requested by output format.
# createdb <REPO_PATH>/data/contam/masking/combined_entropy_masked.fasta <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query --shuffle 0 --threads 14 -v 3
#
# Converting sequences
# [====================================================================
# Time for merging to query_h: 0h 0m 0s 6ms
# Time for merging to query: 0h 0m 0s 7ms
# Database type: Nucleotide
# Time for processing: 0h 0m 2s 24ms
# createdb <REPO_PATH>/data/contam/rrna/silva_rrna_sequences_deduplicated.fasta <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target --shuffle 0 --write-lookup 0 --threads 14 --gpu 0 -v 3
#
# Converting sequences
# [======================
# Time for merging to target_h: 0h 0m 0s 5ms
# Time for merging to target: 0h 0m 0s 6ms
# Database type: Nucleotide
# Time for processing: 0h 0m 1s 736ms
# Create directory <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/index_tmp
# createlinindex <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/index_tmp --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 0 --hash-shift 67 --kmer-per-seq 21 --kmer-per-seq-scale aa:0.000,nucl:0.200 --min-seq-id 0.7 --adjust-kmer-len 0 --split-memory-limit 0 --ignore-multi-kmer 0 --alph-size aa:21,nucl:5 --max-seq-len 65535 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --check-compatible 0 --search-type 3 --spaced-kmer-mode 1 -v 3 --threads 14 --min-length 30 --max-length 32734 --max-gaps 2147483647 --contig-start-mode 2 --contig-end-mode 2 --orf-start-mode 1 --forward-frames 1,2,3 --reverse-frames 1,2,3 --translation-table 1 --translate 0 --use-all-table-starts 0 --id-offset 0 --create-lookup 0 --compressed 0 --remove-tmp-files 1
#
# createlinindex <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/index_tmp --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 0 --hash-shift 67 --kmer-per-seq 21 --kmer-per-seq-scale aa:0.000,nucl:0.200 --min-seq-id 0.7 --adjust-kmer-len 0 --split-memory-limit 0 --ignore-multi-kmer 0 --alph-size aa:21,nucl:5 --max-seq-len 65535 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --check-compatible 0 --search-type 3 --spaced-kmer-mode 1 -v 3 --threads 14 --min-length 30 --max-length 32734 --max-gaps 2147483647 --contig-start-mode 2 --contig-end-mode 2 --orf-start-mode 1 --forward-frames 1,2,3 --reverse-frames 1,2,3 --translation-table 1 --translate 0 --use-all-table-starts 0 --id-offset 0 --create-lookup 0 --compressed 0 --remove-tmp-files 1
#
# splitsequence <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/index_tmp/16375924321180544713/nucl_split_seq --max-seq-len 65535 --sequence-overlap 0 --sequence-split-mode 1 --headers-split-mode 0 --create-lookup 0 --threads 14 --compressed 0 -v 3
#
# Time for processing: 0h 0m 0s 41ms
# kmerindexdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/index_tmp/16375924321180544713/nucl_split_seq <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 0 --hash-shift 67 --kmer-per-seq 21 --kmer-per-seq-scale aa:0.000,nucl:0.200 --min-seq-id 0.7 --adjust-kmer-len 0 --split-memory-limit 0 --ignore-multi-kmer 0 --alph-size aa:21,nucl:5 --max-seq-len 65535 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --check-compatible 0 --search-type 3 --spaced-kmer-mode 1 -v 3 --threads 14
#
# kmerindexdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/index_tmp/16375924321180544713/nucl_split_seq <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 0 --hash-shift 67 --kmer-per-seq 21 --kmer-per-seq-scale aa:0.000,nucl:0.200 --min-seq-id 0.7 --adjust-kmer-len 0 --split-memory-limit 0 --ignore-multi-kmer 0 --alph-size aa:21,nucl:5 --max-seq-len 65535 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --check-compatible 0 --search-type 3 --spaced-kmer-mode 1 -v 3 --threads 14
#
# Database size: 226832 type: Nucleotide
#
# Process file into 1 parts
# Generate k-mers list 0
# [=================================================================] 226.83K 3s 289ms
#
# Adjusted k-mer length 17
#
# Time for fill: 0h 0m 3s 319ms
# Sort kmer ... Time for sort: 0h 0m 1s 701ms
# Write VERSION (0)
# Write META (1)
# Write ENTRIES (9)
# Write ENTRIESOFFSETS (10)
# Write ENTRIESGRIDSIZE (11)
# Write ENTRIESNUM (12)
# Write SEQCOUNT (13)
# Write SCOREMATRIXNAME (2)
# Write SPACEDPATTERN (23)
# Write DBR1INDEX (5)
# Write DBR1DATA (6)
# Write DBR2INDEX (7)
# Write DBR2DATA (8)
# Write HDR1INDEX (18)
# Write HDR1DATA (19)
# Write HDR2INDEX (20)
# Write HDR2DATA (21)
# Write GENERATOR (22)
# Time for fill: 0h 0m 1s 121ms
# Time for merging to target.linidx: 0h 0m 0s 7ms
# Time for processing: 0h 0m 6s 708ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/index_tmp/16375924321180544713/nucl_split_seq -v 3
#
# Time for processing: 0h 0m 0s 8ms
# Create directory <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp
# linsearch <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/result <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp -a 1 --alignment-mode 3 --min-seq-id 0.7 --min-aln-len 80 --max-accept 1231 --threads 14 -v 3 --search-type 3 --remove-tmp-files 1
#
# linsearch <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/result <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp -a 1 --alignment-mode 3 --min-seq-id 0.7 --min-aln-len 80 --max-accept 1231 --threads 14 -v 3 --search-type 3 --remove-tmp-files 1
#
# kmersearch <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/pref --seed-sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --kmer-per-seq 21 --kmer-per-seq-scale aa:0.000,nucl:0.200 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --cov-mode 0 -c 0 --max-seq-len 65535 --pick-n-sim-kmer 1 --result-direction 1 --split-memory-limit 0 --threads 14 --compressed 0 -v 3
#
# kmersearch <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/pref --seed-sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --kmer-per-seq 21 --kmer-per-seq-scale aa:0.000,nucl:0.200 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --cov-mode 0 -c 0 --max-seq-len 65535 --pick-n-sim-kmer 1 --result-direction 1 --split-memory-limit 0 --threads 14 --compressed 0 -v 3
#
# Process file into 1 parts
# [=================================================================] 680.81K 3s 146ms
#
# Adjusted k-mer length 17
#
# Time for fill: 0h 0m 3s 188ms
# Sort kmer ... Time for sort: 0h 0m 3s 80ms
# Time to find k-mers: 0h 0m 0s 426ms
# Time to sort: 0h 0m 0s 14ms
# Time for merging to pref: 0h 0m 0s 23ms
# Time for processing: 0h 0m 7s 303ms
# rescorediagonal <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/pref <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/reverse_ungapaln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 2 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.9 -a 1 --cov-mode 1 --min-seq-id 0.7 --min-aln-len 80 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 14 --compressed 0 -v 3
#
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# [=================================================================] 126.39K 2s 78ms
# Time for merging to reverse_ungapaln: 0h 0m 0s 100ms
# Time for processing: 0h 0m 2s 440ms
# filterdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/pref <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/pref_filter --filter-file <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/reverse_ungapaln --positive-filter 0
#
# Filtering using file(s)
# [=================================================================] 126.39K 0s 11ms
# Time for merging to pref_filter: 0h 0m 0s 171ms
# Time for processing: 0h 0m 0s 427ms
# align <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/pref_filter <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/reverse_aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 1 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 100000 --min-seq-id 0.7 --min-aln-len 80 --seq-id-mode 0 --alt-ali 0 -c 0 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 1231 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 14 --compressed 0 -v 3
#
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# Compute score, coverage and sequence identity
# Query database size: 226832 type: Nucleotide
# Target database size: 680809 type: Nucleotide
# Calculation of alignments
# [=================================================================] 126.39K 2s 997ms
# Time for merging to reverse_aln: 0h 0m 0s 185ms
# 1009369 alignments calculated
# 703 sequence pairs passed the thresholds (0.000696 of overall calculated)
# 0.005562 hits per query sequence
# Time for processing: 0h 0m 3s 440ms
# swapresults <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/reverse_aln <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -e 0.001 --split-memory-limit 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --threads 14 --compressed 0 --db-load-mode 0 -v 3
#
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# Computing offsets.
# [=================================================================] 126.39K 0s 5ms
#
# Reading results.
# [=================================================================] 126.39K 0s 5ms
#
# Output database: <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/aln
# [=================================================================] 680.81K 0s 143ms
#
# Time for merging to aln: 0h 0m 0s 249ms
# Time for processing: 0h 0m 0s 529ms
# swapresults <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/reverse_ungapaln <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/ungap_aln
#
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# Computing offsets.
# [=================================================================] 126.39K 0s 2ms
#
# Reading results.
# [=================================================================] 126.39K 0s 3ms
#
# Output database: <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/ungap_aln
# [=================================================================] 680.81K 0s 154ms
#
# Time for merging to ungap_aln: 0h 0m 0s 318ms
# Time for processing: 0h 0m 0s 649ms
# concatdbs <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/ungap_aln <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/aln <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/aln_merged --preserve-keys --take-larger-entry
#
# [=================================================================] 680.81K 0s 101ms
# [=================================================================] 680.81K 0s 155ms
# Time for merging to aln_merged: 0h 0m 0s 105ms
# Time for processing: 0h 0m 0s 466ms
# offsetalignment <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/aln_merged <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/result
#
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# Computing ORF lookup
# Computing contig offsets
# Computing contig lookup
# Time for contig lookup: 0h 0m 0s 10ms
# Writing results to: <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/result
# [=================================================================] 680.81K 0s 72ms
#
# Time for merging to result: 0h 0m 0s 371ms
# Time for processing: 0h 0m 0s 849ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/pref -v 3
#
# Time for processing: 0h 0m 0s 8ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/search_tmp/8721202811700931978/reverse_aln -v 3
#
# Time for processing: 0h 0m 0s 31ms
# convertalis <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/result <REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --format-mode 1 --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits --translation-table 1 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --db-output 0 --db-load-mode 0 --search-type 3 --threads 14 --compressed 0 -v 3
#
# [=================================================================] 680.81K 0s 80ms
# Time for merging to tmp_mapped.sam: 0h 0m 0s 270ms
# Time for processing: 0h 0m 0s 716ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/result -v 3
#
# Time for processing: 0h 0m 0s 55ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target -v 3
#
# Time for processing: 0h 0m 0s 37ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/target_h -v 3
#
# Time for processing: 0h 0m 0s 6ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query -v 3
#
# Time for processing: 0h 0m 0s 70ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/5693842807573795636/query_h -v 3
#
# Time for processing: 0h 0m 0s 10ms
# File '<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam' size
# is 236303 bytes (not empty).
# INFO     2025-12-28 22:56:03 - Finished running aligner mmseqs2                                                                        ]8;id=816392;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py\mask_dna.py]8;;\:]8;id=867661;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py#220\220]8;;\
# INFO     2025-12-28 22:56:03 - beginning bbmask (masking + entropy) step                                                               ]8;id=611612;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py\mask_dna.py]8;;\:]8;id=125819;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py#221\221]8;;\
# INFO     2025-12-28 22:56:03 - equivalent to bbmask.sh                                                                                 ]8;id=327577;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py\mask_dna.py]8;;\:]8;id=433601;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py#226\226]8;;\
#          in=<REPO_PATH>/data/contam/rrna/silva_rrna_sequences_deduplicated.fasta
#          out=<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_masked.fasta
#          sam=<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam overwrite=true
#          threads=14 Xmx=18g
# java -ea  --add-modules jdk.incubator.vector -Xmx18g -Xms18g -cp
# <REPO_PATH>/.pixi/envs/dev/lib/python3.9/site-packages/bbmapy/vendor/
# bbmap/current/ jgi.BBMask
# in=<REPO_PATH>/data/contam/rrna/silva_rrna_sequences_deduplicated.fas
# ta out=<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_masked.fasta
# sam=<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam
# overwrite=true threads=14 -Xmx18g
# WARNING: Using incubator modules: jdk.incubator.vector
# Executing jgi.BBMask
# [in=<REPO_PATH>/data/contam/rrna/silva_rrna_sequences_deduplicated.fa
# sta, out=<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_masked.fasta,
# sam=<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam,
# overwrite=true, threads=14, -Xmx18g]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Set threads to 14
# Loading input
# Loading Time:                   1.552 seconds.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Masking low-entropy (to disable, set 'mle=f')
# Low Complexity Masking Time:    0.989 seconds.
# Ref Bases:                 431916037    436.73m bases/sec
# Low Complexity Bases:          17198
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Masking from sam
# Sam Masking Time:               0.154 seconds.
# Sam Reads Processed:             587    3.82k reads/sec
# Sam Bases Processed:          116335    0.76m bases/sec
# Sam Bases Masked:             109930
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Converting masked bases to N
# Done Masking
# Conversion Time:                0.546 seconds.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Writing output
# Writing Time:                   0.660 seconds.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Total Bases Masked:           127128/431916037  0.029%
# Total Time:                     4.004 seconds.
# INFO     2025-12-28 22:56:07 - Finished bbmask step                                                                                    ]8;id=776703;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py\mask_dna.py]8;;\:]8;id=18232;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py#235\235]8;;\
# INFO     2025-12-28 22:56:07 - Masking completed. Output saved to                                                                      ]8;id=219745;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py\mask_dna.py]8;;\:]8;id=341603;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py#271\271]8;;\
#          <REPO_PATH>/data/contam/rrna/silva_rrna_sequences_deduplicated_masked.fasta
# java -ea  --add-modules jdk.incubator.vector -Xmx8750m -Xms8750m -cp
# <REPO_PATH>/.pixi/envs/dev/lib/python3.9/site-packages/bbmapy/vendor/
# bbmap/current/ jgi.BBDuk
# in1=<REPO_PATH>/data/contam/rrna/silva_rrna_sequences_deduplicated_ma
# sked.fasta
# out=<REPO_PATH>/data/contam/rrna/silva_rrna_sequences_deduplicated_ma
# sked_entropy.fasta entropy=0.4 entropyk=4 entropywindow=24 maskentropy ziplevel=9
# WARNING: Using incubator modules: jdk.incubator.vector
# Executing jgi.BBDuk
# [in1=<REPO_PATH>/data/contam/rrna/silva_rrna_sequences_deduplicated_m
# asked.fasta,
# out=<REPO_PATH>/data/contam/rrna/silva_rrna_sequences_deduplicated_ma
# sked_entropy.fasta, entropy=0.4, entropyk=4, entropywindow=24, maskentropy, ziplevel=9]
# Version 39.55
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Allocating kmer table:  0.035 seconds.
# Initial:
# Memory: max=9177m, total=9177m, free=9120m, used=57m
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Input is being processed as unpaired
# Started output streams: 0.051 seconds.
# Processing time:                1.756 seconds.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Input:                          226832 reads            431916037 bases.
# Entropy-masked:                 255 reads (0.11%)       7917 bases (0.00%)
# Total Removed:                  0 reads (0.00%)         0 bases (0.00%)
# Result:                         226832 reads (100.00%)  431916037 bases (100.00%)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Time:                           1.808 seconds.
# Reads Processed:        226k    125.46k reads/sec
# Bases Processed:        431m    238.89m bases/sec
# Finished writing SILVA rRNA sequences parquet file.
# finished writing masked SILVA rRNA fasta file: <REPO_PATH>/data/contam/rrna/silva_rRNA_all_sequences_masked_entropy.fasta

# %%
fetch_and_extract(
    url="https://ftp.ncbi.nlm.nih.gov/genomes/genbank/assembly_summary_genbank.txt",
    fetched_to=os.path.join(rrna_dir, "assembly_summary_genbank.txt.gz"),
    extract=False,
)
print("Loading NCBI GenBank assembly summary")
# genbank_summary = pl.read_csv(os.path.join(rrna_dir, "assembly_summary_genbank.txt.gz",),
# infer_schema_length=100020, separator="\t", skip_rows=1,
# null_values=["na","NA","-"],ignore_errors=True,
# has_header=True)
# polars failed me, so using line by line iterator
from gzip import open as gz_open
with gz_open(
    os.path.join(rrna_dir, "assembly_summary_genbank.txt.gz"), "r"
) as f:
    header = None
    records = []
    i = 0
    for line in f:
        if i == 0:
            i += 1
            continue
        line = line.rstrip(b"\n")
        if i == 1:
            header = line.decode()[1:].strip().split("\t")
            i += 1
            continue
        fields = line.decode().strip().split("\t")
        record = dict(zip(header, fields))
        records.append(record)
genbank_summary = pl.from_records(records).rename({"taxid": "ncbi_taxonid"})
genbank_summary.collect_schema()
    # Schema([('assembly_accession', String),
#         ('bioproject', String),
#         ('biosample', String),
#         ('wgs_master', String),
#         ('refseq_category', String),
#         ('ncbi_taxonid', String),
#         ('species_taxid', String),
#         ('organism_name', String),
#         ('infraspecific_name', String),
#         ('isolate', String),
#         ('version_status', String),
#         ('assembly_level', String),
#         ('release_type', String),
#         ('genome_rep', String),
#         ('seq_rel_date', String),
#         ('asm_name', String),
#         ('asm_submitter', String),
#         ('gbrs_paired_asm', String),
#         ('paired_asm_comp', String),
#         ('ftp_path', String),
#         ('excluded_from_refseq', String),
#         ('relation_to_type_material', String),
#         ('asm_not_live_date', String),
#         ('assembly_type', String),
#         ('group', String),
#         ('genome_size', String),
#         ('genome_size_ungapped', String),
#         ('gc_percent', String),
#         ('replicon_count', String),
#         ('scaffold_count', String),
#         ('contig_count', String),
#         ('annotation_provider', String),
#         ('annotation_name', String),
#         ('annotation_date', String),
#         ('total_gene_count', String),
#         ('protein_coding_gene_count', String),
#         ('non_coding_gene_count', String),
#         ('pubmed_id', String)])

genbank_summary.write_csv(
    os.path.join(rrna_dir, "genbank_assembly_summary.tsv"), separator="\t"
)
genbank_summary = pl.read_csv(
    os.path.join(rrna_dir, "genbank_assembly_summary.tsv"),
    infer_schema_length=100020,
    separator="\t",
    null_values=["na", "NA", "-"],
    ignore_errors=True,
    has_header=True,
)

# In [91]: genbank_summary.collect_schema()
# Out[91]: 
# Schema([('assembly_accession', String),
#         ('bioproject', String),
#         ('biosample', String),
#         ('wgs_master', String),
#         ('refseq_category', String),
#         ('ncbi_taxonid', Int64),
#         ('species_taxid', Int64),
#         ('organism_name', String),
#         ('infraspecific_name', String),
#         ('isolate', String),
#         ('version_status', String),
#         ('assembly_level', String),
#         ('release_type', String),
#         ('genome_rep', String),
#         ('seq_rel_date', String),
#         ('asm_name', String),
#         ('asm_submitter', String),
#         ('gbrs_paired_asm', String),
#         ('paired_asm_comp', String),
#         ('ftp_path', String),
#         ('excluded_from_refseq', String),
#         ('relation_to_type_material', String),
#         ('asm_not_live_date', String),
#         ('assembly_type', String),
#         ('group', String),
#         ('genome_size', Int64),
#         ('genome_size_ungapped', Int64),
#         ('gc_percent', Float64),
#         ('replicon_count', Int64),
#         ('scaffold_count', Int64),
#         ('contig_count', Int64),
#         ('annotation_provider', String),
#         ('annotation_name', String),
#         ('annotation_date', String),
#         ('total_gene_count', Int64),
#         ('protein_coding_gene_count', Int64),
#         ('non_coding_gene_count', Int64),
#         ('pubmed_id', String)])

genbank_summary.write_parquet(
    os.path.join(rrna_dir, "genbank_assembly_summary.parquet")
)
# Out:
# INFO     2025-12-28 21:12:54 - Downloading https://ftp.ncbi.nlm.nih.gov/genomes/genbank/assembly_summary_genbank.txt to                 ]8;id=200560;file://<REPO_PATH>/src/rolypoly/utils/various.py\various.py]8;;\:]8;id=689039;file://<REPO_PATH>/src/rolypoly/utils/various.py#215\215]8;;\
#          <REPO_PATH>/data/contam/rrna/assembly_summary_genbank.txt.gz
# INFO     2025-12-28 21:13:31 - Successfully downloaded to                                                                               ]8;id=244576;file://<REPO_PATH>/src/rolypoly/utils/various.py\various.py]8;;\:]8;id=981640;file://<REPO_PATH>/src/rolypoly/utils/various.py#221\221]8;;\
#          <REPO_PATH>/data/contam/rrna/assembly_summary_genbank.txt.gz
# Loading NCBI GenBank assembly summary

# %% [markdown]
# Now the same for refseq as I'm not sure genbank contain all of the stuff in refseq?

# %%
fetch_and_extract(
    url="https://ftp.ncbi.nlm.nih.gov/genomes/refseq/assembly_summary_refseq.txt",
    fetched_to=os.path.join(rrna_dir, "assembly_summary_refseq.txt.gz"),
    extract=False,
)
print("Loading NCBI RefSeq assembly summary")
# refseq_summary = pl.read_csv(os.path.join(rrna_dir, "assembly_summary_refseq.txt.gz",),
# infer_schema_length=100020, separator="\t", skip_rows=1,
# null_values=["na","NA","-"],ignore_errors=True,
# has_header=True)
# polars failed me, so using line by line iterator
from gzip import open as gz_open
with gz_open(
    os.path.join(rrna_dir, "assembly_summary_refseq.txt.gz"), "r"
) as f:
    header = None
    records = []
    i = 0
    for line in f:
        if i == 0:
            i += 1
            continue
        line = line.rstrip(b"\n")
        if i == 1:
            header = line.decode()[1:].strip().split("\t")
            i += 1
            continue
        fields = line.decode().strip().split("\t")
        record = dict(zip(header, fields))
        records.append(record)
refseq_summary = pl.from_records(records).rename({"taxid": "ncbi_taxonid"})
refseq_summary.collect_schema()
    # Schema([('assembly_accession', String),
#         ('bioproject', String),
#         ('biosample', String),
#         ('wgs_master', String),
#         ('refseq_category', String),
#         ('ncbi_taxonid', String),
#         ('species_taxid', String),
#         ('organism_name', String),
#         ('infraspecific_name', String),
#         ('isolate', String),
#         ('version_status', String),
#         ('assembly_level', String),
#         ('release_type', String),
#         ('genome_rep', String),
#         ('seq_rel_date', String),
#         ('asm_name', String),
#         ('asm_submitter', String),
#         ('gbrs_paired_asm', String),
#         ('paired_asm_comp', String),
#         ('ftp_path', String),
#         ('excluded_from_refseq', String),
#         ('relation_to_type_material', String),
#         ('asm_not_live_date', String),
#         ('assembly_type', String),
#         ('group', String),
#         ('genome_size', String),
#         ('genome_size_ungapped', String),
#         ('gc_percent', String),
#         ('replicon_count', String),
#         ('scaffold_count', String),
#         ('contig_count', String),
#         ('annotation_provider', String),
#         ('annotation_name', String),
#         ('annotation_date', String),
#         ('total_gene_count', String),
#         ('protein_coding_gene_count', String),
#         ('non_coding_gene_count', String),
#         ('pubmed_id', String)])

refseq_summary.write_csv(
    os.path.join(rrna_dir, "refseq_assembly_summary.tsv"), separator="\t"
)
refseq_summary = pl.read_csv(
    os.path.join(rrna_dir, "refseq_assembly_summary.tsv"),
    infer_schema_length=100020,
    separator="\t",
    null_values=["na", "NA", "-"],
    ignore_errors=True,
    has_header=True,
)

# In [91]: refseq_summary.collect_schema()
# # Out[91]: 
# Schema([('assembly_accession', String),
#         ('bioproject', String),
#         ('biosample', String),
#         ('wgs_master', String),
#         ('refseq_category', String),
#         ('ncbi_taxonid', Int64),
#         ('species_taxid', Int64),
#         ('organism_name', String),
#         ('infraspecific_name', String),
#         ('isolate', String),
#         ('version_status', String),
#         ('assembly_level', String),
#         ('release_type', String),
#         ('genome_rep', String),
#         ('seq_rel_date', String),
#         ('asm_name', String),
#         ('asm_submitter', String),
#         ('gbrs_paired_asm', String),
#         ('paired_asm_comp', String),
#         ('ftp_path', String),
#         ('excluded_from_refseq', String),
#         ('relation_to_type_material', String),
#         ('asm_not_live_date', String),
#         ('assembly_type', String),
#         ('group', String),
#         ('genome_size', Int64),
#         ('genome_size_ungapped', Int64),
#         ('gc_percent', Float64),
#         ('replicon_count', Int64),
#         ('scaffold_count', Int64),
#         ('contig_count', Int64),
#         ('annotation_provider', String),
#         ('annotation_name', String),
#         ('annotation_date', String),
#         ('total_gene_count', Int64),
#         ('protein_coding_gene_count', Int64),
#         ('non_coding_gene_count', Int64),
#         ('pubmed_id', String)])
refseq_summary.write_parquet(
    os.path.join(rrna_dir, "refseq_assembly_summary.parquet")
)
# Out:
# INFO     2025-12-28 21:17:12 - Downloading https://ftp.ncbi.nlm.nih.gov/genomes/refseq/assembly_summary_refseq.txt to                   ]8;id=867597;file://<REPO_PATH>/src/rolypoly/utils/various.py\various.py]8;;\:]8;id=118293;file://<REPO_PATH>/src/rolypoly/utils/various.py#215\215]8;;\
#          <REPO_PATH>/data/contam/rrna/assembly_summary_refseq.txt.gz
# INFO     2025-12-28 21:17:20 - Successfully downloaded to                                                                               ]8;id=777524;file://<REPO_PATH>/src/rolypoly/utils/various.py\various.py]8;;\:]8;id=5085;file://<REPO_PATH>/src/rolypoly/utils/various.py#221\221]8;;\
#          <REPO_PATH>/data/contam/rrna/assembly_summary_refseq.txt.gz
# Loading NCBI RefSeq assembly summary

# %%
genbank_summary = pl.read_parquet(
    os.path.join(rrna_dir, "genbank_assembly_summary.parquet")
)
refseq_summary = pl.read_parquet(
    os.path.join(rrna_dir, "refseq_assembly_summary.parquet")
)
test=set(genbank_summary.columns).intersection(set(refseq_summary.columns))
print(test)
print(len(test))
# is refseqs in genbank?
refseq_in_genbank = refseq_summary.join(
    genbank_summary.select(["assembly_accession"]).unique(),
    on=["assembly_accession"],
    how="inner",
)
print(f"Total of {refseq_in_genbank.height} RefSeq assemblies found in GenBank assemblies")
ncbi_summary = pl.concat([genbank_summary, refseq_summary],how="diagonal_relaxed").unique(subset=["assembly_accession"])
ncbi_summary.write_parquet(
    os.path.join(rrna_dir, "ncbi_assembly_summary.parquet")
)
ncbi_summary.write_csv(
    os.path.join(rrna_dir, "ncbi_assembly_summary.tsv"), separator="\t"
) 
print(f"Total of {ncbi_summary.height} unique assemblies found in NCBI GenBank and RefSeq")
# Out:
# {'total_gene_count', 'version_status', 'annotation_date', 'non_coding_gene_count', 'biosample', 'pubmed_id', 'bioproject', 'species_taxid', 'assembly_type', 'scaffold_count', 'protein_coding_gene_count', 'assembly_accession', 'ncbi_taxonid', 'seq_rel_date', 'genome_size', 'asm_submitter', 'genome_size_ungapped', 'annotation_name', 'genome_rep', 'isolate', 'asm_name', 'wgs_master', 'replicon_count', 'refseq_category', 'infraspecific_name', 'organism_name', 'gbrs_paired_asm', 'group', 'assembly_level', 'excluded_from_refseq', 'paired_asm_comp', 'ftp_path', 'gc_percent', 'release_type', 'contig_count', 'asm_not_live_date', 'relation_to_type_material', 'annotation_provider'}
# 38
# Total of 0 RefSeq assemblies found in GenBank assemblies
# Total of 3718859 unique assemblies found in NCBI GenBank and RefSeq

# %% [markdown]
# Looks like they are not in genbank, so stacking them

# %%
ncbi_summary = pl.read_parquet(
    os.path.join(rrna_dir, "ncbi_assembly_summary.parquet")
)

# %%
# next, for every unique ncbi_taxonid, we select the one that has the most protein_coding_gene_count, then refseq_category, then tie breaking with non_coding_gene_count, tie breaking by latest assembly (by seq_rel_date).
mini_ncbi = ncbi_summary.sort(
    by=[
        pl.col("refseq_category").reverse(),
        pl.col("protein_coding_gene_count").cast(pl.Int64).reverse(),
        pl.col("non_coding_gene_count").cast(pl.Int64).reverse(),
        pl.col("seq_rel_date").reverse(),
        pl.col("genome_size").reverse(),
    ]
).unique(subset=["ncbi_taxonid"], keep="first")
print(
    f"Filtered GenBank summary to {mini_ncbi.height} unique taxid entries for SILVA sequences"
)

# # in_silva = mini_ncbi.filter(pl.col("ncbi_taxonid").is_in(silva_taxmap["ncbi_taxonid"])).unique()
# print(in_silva.height)
# print(temp_genbank.height)
# only 30503 out of ~240k?
# Out:
# Filtered GenBank summary to 244185 unique taxid entries for SILVA sequences

# %% [markdown]
# ## rRNAs, tRNA, mtDNA, and plastid-DNA from NCBI BLAST DBs

# %% [markdown]
# This is a little hacky, but works?

# %% [markdown]
# rRNAs

# %%
# first, getting the contents of https://ftp.ncbi.nlm.nih.gov/blast/db/ and filtering to files containing "16S", "18S", "28S", "ITS" 
# LSU, SSU

terms = ["16S", "18S", "28S", "ITS", "LSU", "SSU", "ribosomal"]
files_2_download = []
FTP_HOST = "ftp.ncbi.nlm.nih.gov"
FTP_DIR = "/blast/db/"

# List to store the file and directory names
file_list = []

# Connect to the FTP host
with FTP(FTP_HOST) as ftp:
    #  Log in anonymously (default behavior for .login())
    ftp.login()
    print(f"Connected to {FTP_HOST}")
    ftp.cwd(FTP_DIR)
    logger.debug(f"Changed directory to {FTP_DIR}")

    # nlst() returns only names, not detailed information
    file_list = ftp.nlst()
    
    print("\n--- Directory Contents ---")
    for item in file_list:
        if any(term in item for term in terms):
            files_2_download.append(item)
            logger.debug(item)
            
            # Download file directly using FTP
            local_path = os.path.join(rrna_dir, item)
            print(f"Downloading {item}")
            with open(local_path, 'wb') as local_file:
                ftp.retrbinary(f'RETR {item}', local_file.write)
            logger.debug(f"Successfully downloaded {item}")

print(f"Downloaded {len(files_2_download)} files matching terms: {terms}")

# %%
# for each of these, will run blastdbcmd to extract sequences into fasta 
for item in files_2_download:
    if not item.endswith('.tar.gz'):
        continue
    print(f"Processing {item}...")
    extract(archive_path=os.path.join(rrna_dir, item),
        extract_to=rrna_dir,
    )
    # blastdbcmd -entry all -db LSU_prokaryote_rRNA  -out reference.fasta -outfmt "%T;%t;%s" # taxid;header;sequence
    run_command_comp(
        base_cmd="blastdbcmd",
        positional_args=[
            "-entry",
            "all",
            "-db",
            os.path.join(rrna_dir, item.replace('.tar.gz','')),
            "-out",
            os.path.join(rrna_dir, item.replace('.tar.gz','').replace('.tar','') + '.tab'),
            "-outfmt",
            str(f'"%T@%t@%K@%s"') ,
        ],
        positional_args_location="end",
        params={},
        logger=logger,
        output_file=os.path.join(rrna_dir, item.replace('.tar.gz','').replace('.tar','') + '.tab')
    )

# %%
# get all files to remove (everything but the .tab files)
all_files_in_rrna = glob.glob(os.path.join(rrna_dir, "*"))
all_tab_files = glob.glob(os.path.join(rrna_dir, "*.tab"))
all_fasta_files = glob.glob(os.path.join(rrna_dir, "*.fasta"))

# Files to keep (tab files, fasta files, and parquet/tsv files)
files_to_keep = set(all_tab_files + all_fasta_files + 
                   glob.glob(os.path.join(rrna_dir, "*.parquet")) +
                   glob.glob(os.path.join(rrna_dir, "*.tsv")) +
                   glob.glob(os.path.join(rrna_dir, "*.gz")))

# Get all files to remove (exclude directories and files to keep)
files_2_remove = [f for f in all_files_in_rrna if os.path.isfile(f) and f not in files_to_keep]

print(f"Found {len(files_2_remove)} files to remove")
print(f"Keeping {len(files_to_keep)} files (.tab, .fasta, .parquet, .tsv, .gz)")

# Remove the files
for file_path in files_2_remove:
    try:
        os.remove(file_path)
        print(f"Removed: {os.path.basename(file_path)}")
    except Exception as e:
        print(f"Failed to remove {os.path.basename(file_path)}: {e}")

print("Cleanup complete")
# Out:
# Found 1 files to remove
# Keeping 54 files (.tab, .fasta, .parquet, .tsv, .gz)
# Removed: 18S_fungal_sequences.tar.gz.md5
# Cleanup complete

# %%
rrna_df = pl.scan_csv(
    os.path.join(rrna_dir, "*.tab"),
    separator="@",
    has_header=False,
    null_values = ["N/A"],
    new_columns=["taxid", "header","name","sequence"],
    include_file_paths="type"
).collect()
rrna_df = rrna_df.drop("name")
rrna_df = rrna_df.with_columns(
    rRNA_type=pl.col("type").str.extract(r"([^/]+)\.tab$", 1)
)
rrna_df = rrna_df.drop("type")
print(f"Read {rrna_df.height} rRNA sequences from")
# Out:
# Read 159996 rRNA sequences from

# %%
rrna_df["rRNA_type"].value_counts(sort = True)
# Out:
# shape: (8, 2)
# ┌─────────────────────────┬───────┐
# │ rRNA_type               ┆ count │
# │ ---                     ┆ ---   │
# │ str                     ┆ u32   │
# ╞═════════════════════════╪═══════╡
# │ ITS_eukaryote_sequences ┆ 77582 │
# │ 16S_ribosomal_RNA       ┆ 27708 │
# │ ITS_RefSeq_Fungi        ┆ 19541 │
# │ 28S_fungal_sequences    ┆ 11754 │
# │ SSU_eukaryote_rRNA      ┆ 8784  │
# │ LSU_eukaryote_rRNA      ┆ 6575  │
# │ LSU_prokaryote_rRNA     ┆ 4047  │
# │ 18S_fungal_sequences    ┆ 4005  │
# └─────────────────────────┴───────┘

# %% [markdown]
# ### rename fasta seqs to contam notation
# for files to be used in filtering reads later on, the headers should bew parseable by other rolypoly functions. So renaming them here.
# `taxid@Source@type@seq_md5_hash`
# Using @ as separator as it's not common in fasta headers, and just going to assume the original header doesn't contain @, and that mappers who drop everything after the first white space will just ignore the really long headers
# ```fasta
# >2888294@NCBI@ITS_RefSeq_Fungi@55c18f2cfc8490f5d5cb9b34162a44f5
# atgtgatgaga...
# ```

# %%
import hashlib
rrna_df = rrna_df.with_columns(
    t1=pl.concat_str([pl.col("taxid"),pl.lit("NCBI"),pl.col("rRNA_type")],separator="@")
    )

rrna_df = rrna_df.with_columns(
    pl.col("sequence").map_elements(lambda x: hashlib.md5(x.encode()).hexdigest()).alias("seq_hash"),
).with_columns(
    new_header = pl.concat_str([pl.col("t1"),pl.col("seq_hash")],separator="@")
    
)
rrna_df = rrna_df.unique()
rrna_df = rrna_df.unique(subset=["sequence"])


rrna_df["new_header"].head(1).item()
# Out:
# '2888294@NCBI@ITS_RefSeq_Fungi@55c18f2cfc8490f5d5cb9b34162a44f5'

# %%
rrna_df.height == rrna_df.with_columns(
    header_hash = pl.col("header").map_elements(lambda x: hashlib.md5(x.encode()).hexdigest())).select("header_hash").unique().height
# Out:
# False

# %% [markdown]
# Maybe some have more than 1 unique SSU/LSU?

# %%
# rrna_df.with_columns(length=pl.col("sequence").str.len_chars()).select(pl.col("length").min()).item()
# Out:
# 104

# %%
rrna_fasta_path = os.path.join(rrna_dir, "ncbi_rRNA_all_sequences.fasta")

rrna_df = rrna_df.filter(~pl.col("taxid").is_in([77133,155900,115547,256318,100272,136703,171953,86473,56765]))
write_fasta_file(
    seqs=rrna_df["sequence"].to_list(),
    headers=rrna_df["new_header"].to_list(),
    output_file=rrna_fasta_path,
)
print(f"Wrote combined ncbi rRNA fasta to {rrna_fasta_path}")
# Out:
# Wrote combined ncbi rRNA fasta to <REPO_PATH>/data/contam/rrna/ncbi_rRNA_all_sequences.fasta

# %% [markdown]
# Next is the esame entropy and RNA virus masking as above.

# %%
import rich_click as click
# first replace headers with md5 hash as the new_header breaks mappers. Will remap after this
write_fasta_file(
    headers=rrna_df["new_header"].to_list(),
    seqs=rrna_df["sequence"].to_list(),
    output_file=os.path.join(rrna_dir, "temp_ncbi_rRNA_all_sequences.fasta"),
)

# mask shared kmers with RNA viruses
masked_ncbi_fasta_path = os.path.join(
    rrna_dir, "temp_ncbi_rRNA_all_sequences_masked.fasta"
)

entrophy_masked_ncbi_fasta_path = os.path.join(
    rrna_dir, "temp_ncbi_rRNA_all_sequences_masked_entropy.fasta"
)

mask_args = {"threads": 15,
            "memory": "68gb",
            "output": str(masked_ncbi_fasta_path),
            "flatten": False,
            "aligner":"mmseqs2",
            "input": os.path.join(rrna_dir, "temp_ncbi_rRNA_all_sequences.fasta")
        }

# ensure we have the click Command object (the package import may have bound the module)
from rolypoly.commands.reads.mask_dna import mask_dna as _mask_cmd

# If it's a click.Command use a Context to invoke, otherwise call directly
if isinstance(_mask_cmd, click.core.Command):
    ctx = click.Context(_mask_cmd)
    ctx.invoke(_mask_cmd, **mask_args)
else:
    # fallback: call the function directly
    _mask_cmd(**mask_args)

# # Apply entropy masking
bbduk(
    in1=masked_ncbi_fasta_path,
    out=entrophy_masked_ncbi_fasta_path,
    entropy=0.4,
    entropyk=4,
    entropywindow=24,
    maskentropy=True,
    threads=15,
)

# read the masked fasta and remap to original headers
ncbi_rrna_masked_df = from_fastx_eager(entrophy_masked_ncbi_fasta_path).rename({"header":"new_header","sequence":"masked_sequence"})
ncbi_rrna_masked_df = ncbi_rrna_masked_df.join(
    rrna_df,
    on=["new_header"],
    how="inner",
)
ncbi_rrna_masked_df.write_parquet(os.path.join(rrna_dir, "ncbi_rrna_sequences_masked.parquet"))
print("Finished writing NCBI rRNA sequences parquet file.")
write_fasta_file(
    headers=ncbi_rrna_masked_df["new_header"].to_list(),
    seqs=ncbi_rrna_masked_df["masked_sequence"].to_list(),
    output_file=os.path.join(rrna_dir, "ncbi_rRNA_all_sequences_masked_entropy.fasta"),
)
print(f"finished writing masked NCBI rRNA fasta file: {os.path.join(rrna_dir, 'ncbi_rRNA_all_sequences_masked_entropy.fasta')}")
# Out:
# INFO     2025-12-28 22:47:10 - datadir used: <REPO_PATH>/data                             ]8;id=933960;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py\mask_dna.py]8;;\:]8;id=343840;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py#71\71]8;;\
# Running command: mmseqs easy-linsearch <REPO_PATH>/data/contam/masking/combined_entropy_masked.fasta <REPO_PATH>/data/contam/rrna/temp_ncbi_rRNA_all_sequences.fasta <REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam <REPO_PATH>/data/contam/rrna/tmp_mask_dna  --min-seq-id 0.7 --min-aln-len 80 --threads 15 --format-mode 1 --search-type 3 -v 3 --max-accept 1231 -a
# easy-linsearch <REPO_PATH>/data/contam/masking/combined_entropy_masked.fasta <REPO_PATH>/data/contam/rrna/temp_ncbi_rRNA_all_sequences.fasta <REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam <REPO_PATH>/data/contam/rrna/tmp_mask_dna --min-seq-id 0.7 --min-aln-len 80 --threads 15 --format-mode 1 --search-type 3 -v 3 --max-accept 1231 -a
#
# MMseqs Version:                    	18.8cc5c
# Substitution matrix                	aa:blosum62.out,nucl:nucleotide.out
# Add backtrace                      	true
# Alignment mode                     	3
# Alignment mode                     	0
# Allow wrapped scoring              	false
# E-value threshold                  	0.001
# Seq. id. threshold                 	0.7
# Min alignment length               	80
# Seq. id. mode                      	0
# Alternative alignments             	0
# Coverage threshold                 	0
# Coverage mode                      	0
# Max sequence length                	65535
# Compositional bias                 	1
# Compositional bias scale           	1
# Max reject                         	2147483647
# Max accept                         	1231
# Include identical seq. id.         	false
# Preload mode                       	0
# Pseudo count a                     	substitution:1.100,context:1.400
# Pseudo count b                     	substitution:4.100,context:5.800
# Score bias                         	0
# Realign hits                       	false
# Realign score bias                 	-0.2
# Realign max seqs                   	2147483647
# Correlation score weight           	0
# Gap open cost                      	aa:11,nucl:5
# Gap extension cost                 	aa:1,nucl:2
# Zdrop                              	40
# Threads                            	15
# Compressed                         	0
# Verbosity                          	3
# Seed substitution matrix           	aa:VTML80.out,nucl:nucleotide.out
# k-mers per sequence                	21
# Scale k-mers per sequence          	aa:0.000,nucl:0.200
# Mask residues                      	1
# Mask residues probability          	0.9
# Mask lower case residues           	0
# Mask lower letter repeating N times	0
# Add N similar to search            	1
# Result direction                   	1
# Split memory limit                 	0
# Min codons in orf                  	30
# Max codons in length               	32734
# Max orf gaps                       	2147483647
# Contig start mode                  	2
# Contig end mode                    	2
# Orf start mode                     	1
# Forward frames                     	1,2,3
# Reverse frames                     	1,2,3
# Translation table                  	1
# Translate orf                      	0
# Use all table starts               	false
# Offset of numeric ids              	0
# Create lookup                      	0
# Chain overlapping alignments       	0
# Merge query                        	1
# Search type                        	3
# MPI runner
# Force restart with latest tmp      	false
# Remove temporary files             	true
# Alignment format                   	1
# Format alignment output            	query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits
# Database output                    	false
#
# Alignment backtraces will be computed, since they were requested by output format.
# createdb <REPO_PATH>/data/contam/masking/combined_entropy_masked.fasta <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query --shuffle 0 --threads 15 -v 3
#
# Converting sequences
# [====================================================================
# Time for merging to query_h: 0h 0m 0s 5ms
# Time for merging to query: 0h 0m 0s 5ms
# Database type: Nucleotide
# Time for processing: 0h 0m 1s 977ms
# createdb <REPO_PATH>/data/contam/rrna/temp_ncbi_rRNA_all_sequences.fasta <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target --shuffle 0 --write-lookup 0 --threads 15 --gpu 0 -v 3
#
# Converting sequences
# [==============
# Time for merging to target_h: 0h 0m 0s 5ms
# Time for merging to target: 0h 0m 0s 8ms
# Database type: Nucleotide
# Time for processing: 0h 0m 0s 746ms
# Create directory <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/index_tmp
# createlinindex <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/index_tmp --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 0 --hash-shift 67 --kmer-per-seq 21 --kmer-per-seq-scale aa:0.000,nucl:0.200 --min-seq-id 0.7 --adjust-kmer-len 0 --split-memory-limit 0 --ignore-multi-kmer 0 --alph-size aa:21,nucl:5 --max-seq-len 65535 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --check-compatible 0 --search-type 3 --spaced-kmer-mode 1 -v 3 --threads 15 --min-length 30 --max-length 32734 --max-gaps 2147483647 --contig-start-mode 2 --contig-end-mode 2 --orf-start-mode 1 --forward-frames 1,2,3 --reverse-frames 1,2,3 --translation-table 1 --translate 0 --use-all-table-starts 0 --id-offset 0 --create-lookup 0 --compressed 0 --remove-tmp-files 1
#
# createlinindex <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/index_tmp --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 0 --hash-shift 67 --kmer-per-seq 21 --kmer-per-seq-scale aa:0.000,nucl:0.200 --min-seq-id 0.7 --adjust-kmer-len 0 --split-memory-limit 0 --ignore-multi-kmer 0 --alph-size aa:21,nucl:5 --max-seq-len 65535 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --check-compatible 0 --search-type 3 --spaced-kmer-mode 1 -v 3 --threads 15 --min-length 30 --max-length 32734 --max-gaps 2147483647 --contig-start-mode 2 --contig-end-mode 2 --orf-start-mode 1 --forward-frames 1,2,3 --reverse-frames 1,2,3 --translation-table 1 --translate 0 --use-all-table-starts 0 --id-offset 0 --create-lookup 0 --compressed 0 --remove-tmp-files 1
#
# splitsequence <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/index_tmp/15181030682690789959/nucl_split_seq --max-seq-len 65535 --sequence-overlap 0 --sequence-split-mode 1 --headers-split-mode 0 --create-lookup 0 --threads 15 --compressed 0 -v 3
#
# Time for processing: 0h 0m 0s 32ms
# kmerindexdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/index_tmp/15181030682690789959/nucl_split_seq <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 0 --hash-shift 67 --kmer-per-seq 21 --kmer-per-seq-scale aa:0.000,nucl:0.200 --min-seq-id 0.7 --adjust-kmer-len 0 --split-memory-limit 0 --ignore-multi-kmer 0 --alph-size aa:21,nucl:5 --max-seq-len 65535 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --check-compatible 0 --search-type 3 --spaced-kmer-mode 1 -v 3 --threads 15
#
# kmerindexdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/index_tmp/15181030682690789959/nucl_split_seq <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -k 0 --hash-shift 67 --kmer-per-seq 21 --kmer-per-seq-scale aa:0.000,nucl:0.200 --min-seq-id 0.7 --adjust-kmer-len 0 --split-memory-limit 0 --ignore-multi-kmer 0 --alph-size aa:21,nucl:5 --max-seq-len 65535 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --check-compatible 0 --search-type 3 --spaced-kmer-mode 1 -v 3 --threads 15
#
# Database size: 145146 type: Nucleotide
#
# Process file into 1 parts
# Generate k-mers list 0
# [=================================================================] 145.15K 1s 186ms
#
# Adjusted k-mer length 17
#
# Time for fill: 0h 0m 1s 217ms
# Sort kmer ... Time for sort: 0h 0m 0s 568ms
# Write VERSION (0)
# Write META (1)
# Write ENTRIES (9)
# Write ENTRIESOFFSETS (10)
# Write ENTRIESGRIDSIZE (11)
# Write ENTRIESNUM (12)
# Write SEQCOUNT (13)
# Write SCOREMATRIXNAME (2)
# Write SPACEDPATTERN (23)
# Write DBR1INDEX (5)
# Write DBR1DATA (6)
# Write DBR2INDEX (7)
# Write DBR2DATA (8)
# Write HDR1INDEX (18)
# Write HDR1DATA (19)
# Write HDR2INDEX (20)
# Write HDR2DATA (21)
# Write GENERATOR (22)
# Time for fill: 0h 0m 0s 570ms
# Time for merging to target.linidx: 0h 0m 0s 7ms
# Time for processing: 0h 0m 2s 568ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/index_tmp/15181030682690789959/nucl_split_seq -v 3
#
# Time for processing: 0h 0m 0s 8ms
# Create directory <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp
# linsearch <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/result <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp -a 1 --alignment-mode 3 --min-seq-id 0.7 --min-aln-len 80 --max-accept 1231 --threads 15 -v 3 --search-type 3 --remove-tmp-files 1
#
# linsearch <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/result <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp -a 1 --alignment-mode 3 --min-seq-id 0.7 --min-aln-len 80 --max-accept 1231 --threads 15 -v 3 --search-type 3 --remove-tmp-files 1
#
# kmersearch <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/pref --seed-sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --kmer-per-seq 21 --kmer-per-seq-scale aa:0.000,nucl:0.200 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --cov-mode 0 -c 0 --max-seq-len 65535 --pick-n-sim-kmer 1 --result-direction 1 --split-memory-limit 0 --threads 15 --compressed 0 -v 3
#
# kmersearch <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/pref --seed-sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --kmer-per-seq 21 --kmer-per-seq-scale aa:0.000,nucl:0.200 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --cov-mode 0 -c 0 --max-seq-len 65535 --pick-n-sim-kmer 1 --result-direction 1 --split-memory-limit 0 --threads 15 --compressed 0 -v 3
#
# Process file into 1 parts
# [=================================================================] 680.81K 6s 494ms
#
# Adjusted k-mer length 17
#
# Time for fill: 0h 0m 6s 535ms
# Sort kmer ... Time for sort: 0h 0m 2s 883ms
# Time to find k-mers: 0h 0m 0s 376ms
# Time to sort: 0h 0m 0s 12ms
# Time for merging to pref: 0h 0m 0s 26ms
# Time for processing: 0h 0m 10s 478ms
# rescorediagonal <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/pref <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/reverse_ungapaln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 2 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.9 -a 1 --cov-mode 1 --min-seq-id 0.7 --min-aln-len 80 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 15 --compressed 0 -v 3
#
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# [=================================================================] 114.22K 0s 488ms
# Time for merging to reverse_ungapaln: 0h 0m 0s 100ms
# Time for processing: 0h 0m 0s 843ms
# filterdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/pref <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/pref_filter --filter-file <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/reverse_ungapaln --positive-filter 0
#
# Filtering using file(s)
# [=================================================================] 114.22K 0s 14ms
# Time for merging to pref_filter: 0h 0m 0s 209ms
# Time for processing: 0h 0m 0s 480ms
# align <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/pref_filter <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/reverse_aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 1 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 100000 --min-seq-id 0.7 --min-aln-len 80 --seq-id-mode 0 --alt-ali 0 -c 0 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 1231 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 15 --compressed 0 -v 3
#
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# Compute score, coverage and sequence identity
# Query database size: 145146 type: Nucleotide
# Target database size: 680809 type: Nucleotide
# Calculation of alignments
# [=================================================================] 114.22K 2s 442ms
# Time for merging to reverse_aln: 0h 0m 0s 113ms
# 935331 alignments calculated
# 523 sequence pairs passed the thresholds (0.000559 of overall calculated)
# 0.004579 hits per query sequence
# Time for processing: 0h 0m 2s 799ms
# swapresults <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/reverse_aln <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -e 0.001 --split-memory-limit 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --threads 15 --compressed 0 --db-load-mode 0 -v 3
#
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# Computing offsets.
# [=================================================================] 114.22K 0s 8ms
#
# Reading results.
# [=================================================================] 114.22K 0s 4ms
#
# Output database: <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/aln
# [=================================================================] 680.81K 0s 130ms
#
# Time for merging to aln: 0h 0m 0s 221ms
# Time for processing: 0h 0m 0s 493ms
# swapresults <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/reverse_ungapaln <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/ungap_aln
#
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# Computing offsets.
# [=================================================================] 114.22K 0s 5ms
#
# Reading results.
# [=================================================================] 114.22K 0s 3ms
#
# Output database: <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/ungap_aln
# [=================================================================] 680.81K 0s 169ms
#
# Time for merging to ungap_aln: 0h 0m 0s 328ms
# Time for processing: 0h 0m 0s 678ms
# concatdbs <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/ungap_aln <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/aln <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/aln_merged --preserve-keys --take-larger-entry
#
# [=================================================================] 680.81K 0s 100ms
# [=================================================================] 680.81K 0s 154ms
# Time for merging to aln_merged: 0h 0m 0s 102ms
# Time for processing: 0h 0m 0s 437ms
# offsetalignment <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target.linidx <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/aln_merged <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/result
#
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# Index version: 16
# Generated by:  18.8cc5c
# ScoreMatrix:  nucleotide.out
# Computing ORF lookup
# Computing contig offsets
# Computing contig lookup
# Time for contig lookup: 0h 0m 0s 8ms
# Writing results to: <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/result
# [=================================================================] 680.81K 0s 59ms
#
# Time for merging to result: 0h 0m 0s 578ms
# Time for processing: 0h 0m 1s 47ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/pref -v 3
#
# Time for processing: 0h 0m 0s 10ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/search_tmp/7525828659598130507/reverse_aln -v 3
#
# Time for processing: 0h 0m 0s 31ms
# convertalis <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/result <REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --format-mode 1 --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits --translation-table 1 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --db-output 0 --db-load-mode 0 --search-type 3 --threads 15 --compressed 0 -v 3
#
# [=================================================================] 680.81K 0s 80ms
# Time for merging to tmp_mapped.sam: 0h 0m 0s 392ms
# Time for processing: 0h 0m 0s 828ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/result -v 3
#
# Time for processing: 0h 0m 0s 65ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target -v 3
#
# Time for processing: 0h 0m 0s 24ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/target_h -v 3
#
# Time for processing: 0h 0m 0s 6ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query -v 3
#
# Time for processing: 0h 0m 0s 74ms
# rmdb <REPO_PATH>/data/contam/rrna/tmp_mask_dna/2407584767492699454/query_h -v 3
#
# Time for processing: 0h 0m 0s 9ms
# File '<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam' size
# is 191029 bytes (not empty).
# INFO     2025-12-28 22:47:35 - Finished running aligner mmseqs2                                                                        ]8;id=988782;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py\mask_dna.py]8;;\:]8;id=121695;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py#220\220]8;;\
# INFO     2025-12-28 22:47:35 - beginning bbmask (masking + entropy) step                                                               ]8;id=867646;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py\mask_dna.py]8;;\:]8;id=322806;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py#221\221]8;;\
# INFO     2025-12-28 22:47:35 - equivalent to bbmask.sh                                                                                 ]8;id=16356;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py\mask_dna.py]8;;\:]8;id=601432;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py#226\226]8;;\
#          in=<REPO_PATH>/data/contam/rrna/temp_ncbi_rRNA_all_sequences.fasta
#          out=<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_masked.fasta
#          sam=<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam overwrite=true
#          threads=15 Xmx=68g
# java -ea  --add-modules jdk.incubator.vector -Xmx68g -Xms68g -cp
# <REPO_PATH>/.pixi/envs/dev/lib/python3.9/site-packages/bbmapy/vendor/
# bbmap/current/ jgi.BBMask
# in=<REPO_PATH>/data/contam/rrna/temp_ncbi_rRNA_all_sequences.fasta
# out=<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_masked.fasta
# sam=<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam
# overwrite=true threads=15 -Xmx68g
# WARNING: Using incubator modules: jdk.incubator.vector
# Executing jgi.BBMask
# [in=<REPO_PATH>/data/contam/rrna/temp_ncbi_rRNA_all_sequences.fasta,
# out=<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_masked.fasta,
# sam=<REPO_PATH>/data/contam/rrna/tmp_mask_dna/tmp_mapped.sam,
# overwrite=true, threads=15, -Xmx68g]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Set threads to 15
# Loading input
# Loading Time:                   0.499 seconds.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Masking low-entropy (to disable, set 'mle=f')
# Low Complexity Masking Time:    0.373 seconds.
# Ref Bases:                 160837643    430.65m bases/sec
# Low Complexity Bases:          17758
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Masking from sam
# Sam Masking Time:               0.085 seconds.
# Sam Reads Processed:             428    5.04k reads/sec
# Sam Bases Processed:           77637    0.91m bases/sec
# Sam Bases Masked:              75030
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Converting masked bases to N
# Done Masking
# Conversion Time:                0.211 seconds.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Writing output
# Writing Time:                   0.409 seconds.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Total Bases Masked:            92788/160837643  0.058%
# Total Time:                     1.683 seconds.
# INFO     2025-12-28 22:47:37 - Finished bbmask step                                                                                    ]8;id=213621;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py\mask_dna.py]8;;\:]8;id=537910;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py#235\235]8;;\
# INFO     2025-12-28 22:47:37 - Masking completed. Output saved to                                                                      ]8;id=971148;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py\mask_dna.py]8;;\:]8;id=272644;file://<REPO_PATH>/src/rolypoly/commands/reads/mask_dna.py#271\271]8;;\
#          <REPO_PATH>/data/contam/rrna/temp_ncbi_rRNA_all_sequences_masked.fasta
# java -ea  --add-modules jdk.incubator.vector -Xmx14541m -Xms14541m -cp
# <REPO_PATH>/.pixi/envs/dev/lib/python3.9/site-packages/bbmapy/vendor/
# bbmap/current/ jgi.BBDuk
# in1=<REPO_PATH>/data/contam/rrna/temp_ncbi_rRNA_all_sequences_masked.
# fasta
# out=<REPO_PATH>/data/contam/rrna/temp_ncbi_rRNA_all_sequences_masked_
# entropy.fasta entropy=0.4 entropyk=4 entropywindow=24 maskentropy threads=15
# WARNING: Using incubator modules: jdk.incubator.vector
# Executing jgi.BBDuk
# [in1=<REPO_PATH>/data/contam/rrna/temp_ncbi_rRNA_all_sequences_masked
# .fasta,
# out=<REPO_PATH>/data/contam/rrna/temp_ncbi_rRNA_all_sequences_masked_
# entropy.fasta, entropy=0.4, entropyk=4, entropywindow=24, maskentropy, threads=15]
# Version 39.55
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Set threads to 15
# Allocating kmer table:  0.036 seconds.
# Initial:
# Memory: max=15250m, total=15250m, free=15180m, used=70m
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Input is being processed as unpaired
# Started output streams: 0.031 seconds.
# Processing time:                0.785 seconds.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Input:                          145146 reads            160837643 bases.
# Entropy-masked:                 394 reads (0.27%)       12514 bases (0.01%)
# Total Removed:                  0 reads (0.00%)         0 bases (0.00%)
# Result:                         145146 reads (100.00%)  160837643 bases (100.00%)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Time:                           0.816 seconds.
# Reads Processed:        145k    177.86k reads/sec
# Bases Processed:        160m    197.09m bases/sec
# Finished writing NCBI rRNA sequences parquet file.
# finished writing masked NCBI rRNA fasta file: <REPO_PATH>/data/contam/rrna/ncbi_rRNA_all_sequences_masked_entropy.fasta

# %%
temp_df = ncbi_rrna_masked_df.join(
    mini_ncbi.select(
        ["ncbi_taxonid", "organism_name"]
    ).unique(),  # seq_length
    left_on=["taxid"],
    right_on=["ncbi_taxonid"],
    how="left",
)
temp_df["organism_name"].value_counts(sort=True)
# Out:
# shape: (25_057, 2)
# ┌─────────────────────────────────┬────────┐
# │ organism_name                   ┆ count  │
# │ ---                             ┆ ---    │
# │ str                             ┆ u32    │
# ╞═════════════════════════════════╪════════╡
# │ null                            ┆ 105619 │
# │ Globisporangium heterothallicu… ┆ 93     │
# │ Babesia bovis                   ┆ 65     │
# │ Globisporangium sylvaticum      ┆ 61     │
# │ Globisporangium irregulare      ┆ 56     │
# │ …                               ┆ …      │
# │ Sphingobacterium deserti        ┆ 1      │
# │ Pararcticibacter amylolyticus   ┆ 1      │
# │ Leontodon rigens                ┆ 1      │
# │ Bradyrhizobium diversitatis     ┆ 1      │
# │ Botrimarina colliarenosi        ┆ 1      │
# └─────────────────────────────────┴────────┘

# %% [markdown]
# some 105k nulls, these are the ones that will need to patch to link to cloest related organism that does have genome/transcriptome data on genbank.
# That is done in [rrna_genome_mapping_taxonomy.ipynb](rrna_genome_mapping_taxonomy.ipynb)

# %% [markdown]
# ## Now tRNAs

# %%
file_url = "https://ftp.ebi.ac.uk/pub/databases/Rfam/CURRENT/fasta_files/RF00005.fa.gz"
trna_seqs = os.path.join(trna_dir, "tRNA_sequences.fasta")
gz_filename = "RF00005.fa.gz"
fetch_and_extract(
                url=file_url,
                fetched_to=os.path.join(trna_dir, gz_filename),
                extract_to=trna_dir,
                expected_file=trna_seqs,
            )
print(f"Downloaded tRNA sequences to {trna_seqs}")

# %%
# remove duplicates
deduplicated_fasta = os.path.join(trna_dir, "tRNA_sequences_deduplicated.fasta")
remove_duplicates(
    input_file=trna_seqs,
    output_file=deduplicated_fasta,
    return_stats=True,
    by = "seq"
)

# %%
from rolypoly.utils.bio.polars_fastx import compute_aggregate_stats,fasta_stats
info_table = fasta_stats(deduplicated_fasta)
# print(info_table)

some_stats = compute_aggregate_stats(info_table,fields=["length", "gc_content", "n_content"])
some_stats

# %% [markdown]
# I don't trust this (min len 30, min gc 8% ), so will do some light filteration.

# %%
info_table = info_table.filter(
    pl.col("length").is_between(60,250),
    pl.col("gc_content") >= 0.01,
)
some_stats_filtered = compute_aggregate_stats(info_table,fields=["length", "gc_content", "n_content"])
some_stats_filtered
# info_table.write_parquet(os.path.join(trna_dir, "tRNA_sequences_deduplicated_stats.parquet"))

# %% [markdown]
# looks a little better, will just accept that very low or very high GC content tRNAs exist.

# %%
write_fasta_file(
    seqs=info_table["sequence"].to_list(),
    headers=info_table["header"].to_list(),
    output_file=os.path.join(trna_dir, "tRNA_sequences_deduplicated_filtered.fasta"),
)
print(f"Wrote filtered tRNA sequences to {os.path.join(trna_dir, 'tRNA_sequences_deduplicated_filtered.fasta')}")

# %% [markdown]
# ## plastid and mitochondria genomes

# %%
from rolypoly.commands.misc.build_data import prepare_plastid_data, prepare_mito_data
prepare_plastid_data(data_dir, logger)
prepare_mito_data(data_dir, logger)
